# %%
import pandas as pd
import numpy as np
import sqlalchemy

# %% [markdown]
# # Focus on 15 mins ticks

# %%
all_crypto_15 = pd.read_csv('../data/ALL_15.csv')
all_crypto_15.set_index(['open_time'],inplace =True)
all_crypto_15.index = pd.to_datetime(all_crypto_15.index)
all_crypto_15.head()
# Out:
#                      close_AAVEUSDT  close_AUTOUSDT  close_BCHUSDT
# open_time
# 2017-08-17 04:00:00             NaN             NaN            NaN  \
# 2017-08-17 04:15:00             NaN             NaN            NaN
# 2017-08-17 04:30:00             NaN             NaN            NaN
# 2017-08-17 04:45:00             NaN             NaN            NaN
# 2017-08-17 05:00:00             NaN             NaN            NaN
#
#                      close_BETHUSDT  close_BIFIUSDT  close_BNBUSDT
# open_time
# 2017-08-17 04:00:00             NaN             NaN            NaN  \
# 2017-08-17 04:15:00             NaN             NaN            NaN
# 2017-08-17 04:30:00             NaN             NaN            NaN
# 2017-08-17 04:45:00             NaN             NaN            NaN
# 2017-08-17 05:00:00             NaN             NaN            NaN
#
#                      close_BTCUSDT  close_ETHUSDT  close_GMXUSDT
# open_time
# ...

# %% [markdown]
# We check the differents type of all of our variables

# %%
all_crypto_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 197073 entries, 2017-08-17 04:00:00 to 2023-04-01 00:00:00
# Data columns (total 20 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   close_AAVEUSDT   86103 non-null   float64
#  1   close_AUTOUSDT   69890 non-null   float64
#  2   close_BCHUSDT    116928 non-null  float64
#  3   close_BETHUSDT   2748 non-null    float64
#  4   close_BIFIUSDT   35000 non-null   float64
#  5   close_BNBUSDT    188760 non-null  float64
#  6   close_BTCUSDT    196508 non-null  float64
#  7   close_ETHUSDT    196508 non-null  float64
#  8   close_GMXUSDT    17044 non-null   float64
#  9   close_GNOUSDT    55548 non-null   float64
#  10  close_ILVUSDT    53340 non-null   float64
#  11  close_KP3RUSDT   48436 non-null   float64
#  12  close_LTCUSDT    185211 non-null  float64
#  13  close_MKRUSDT    94123 non-null   float64
#  14  close_PAXGUSDT   90675 non-null   float64
# ...

# %%
all_crypto_15.count()
# Out:
# close_AAVEUSDT      86103
# close_AUTOUSDT      69890
# close_BCHUSDT      116928
# close_BETHUSDT       2748
# close_BIFIUSDT      35000
# close_BNBUSDT      188760
# close_BTCUSDT      196508
# close_ETHUSDT      196508
# close_GMXUSDT       17044
# close_GNOUSDT       55548
# close_ILVUSDT       53340
# close_KP3RUSDT      48436
# close_LTCUSDT      185211
# close_MKRUSDT       94123
# close_PAXGUSDT      90675
# close_QNTUSDT       58602
# close_QUICKUSDT     57156
# close_XMRUSDT      141627
# close_YFIIUSDT      90295
# close_YFIUSDT       92403
# dtype: int64

# %%
all_crypto_15.interpolate(methode = 'polynomial')
# Out:
#                      close_AAVEUSDT  close_AUTOUSDT  close_BCHUSDT
# open_time
# 2017-08-17 04:00:00             NaN             NaN            NaN  \
# 2017-08-17 04:15:00             NaN             NaN            NaN
# 2017-08-17 04:30:00             NaN             NaN            NaN
# 2017-08-17 04:45:00             NaN             NaN            NaN
# 2017-08-17 05:00:00             NaN             NaN            NaN
# ...                             ...             ...            ...
# 2023-03-31 23:00:00            74.3           225.9          124.2
# 2023-03-31 23:15:00            74.4           226.1          124.3
# 2023-03-31 23:30:00            74.3           226.0          124.1
# 2023-03-31 23:45:00            74.4           226.2          124.2
# 2023-04-01 00:00:00            74.3           226.0          124.2
#
#                      close_BETHUSDT  close_BIFIUSDT  close_BNBUSDT
# open_time
# 2017-08-17 04:00:00             NaN             NaN            NaN  \
# ...

# %%
all_crypto_15.describe()
# Out:
#        close_AAVEUSDT  close_AUTOUSDT  close_BCHUSDT  close_BETHUSDT
# count    86103.000000    69890.000000  116928.000000     2748.000000  \
# mean       190.550412      721.567528     335.846686     1646.337711
# std        131.682709      773.894680     216.698703      124.061425
# min         26.024000      113.900000      88.100000     1346.500000
# 25%         79.700000      256.025000     178.800000     1542.067500
# 50%        143.400000      398.200000     274.320000     1688.995000
# 75%        303.119500      948.400000     460.212500     1754.740000
# max        665.280000     5988.480000    1632.970000     1827.470000
#
#        close_BIFIUSDT  close_BNBUSDT  close_BTCUSDT  close_ETHUSDT
# count    35000.000000  188760.000000  196508.000000  196508.000000  \
# mean       525.428934     153.914838   19584.441469    1115.160612
# std        313.370556     181.737064   16392.264614    1153.412587
# min        291.500000       1.300000    2817.000000      82.070000
# ...

# %%
pd.DataFrame({'Initial':all_crypto_15.isna().sum(),'Polynomial interpolation':all_crypto_15.interpolate(methode = 'polynomial').isna().sum()})
# Out:
#                  Initial  Polynomial interpolation
# close_AAVEUSDT    110970                    110876
# close_AUTOUSDT    127183                    127124
# close_BCHUSDT      80145                     79992
# close_BETHUSDT    194325                    194320
# close_BIFIUSDT    162073                    162068
# close_BNBUSDT       8313                      7775
# close_BTCUSDT        565                         0
# close_ETHUSDT        565                         0
# close_GMXUSDT     180029                    180024
# close_GNOUSDT     141525                    141512
# close_ILVUSDT     143733                    143720
# close_KP3RUSDT    148637                    148632
# close_LTCUSDT      11862                     11326
# close_MKRUSDT     102950                    102856
# close_PAXGUSDT    106398                    106304
# close_QNTUSDT     138471                    138440
# close_QUICKUSDT   139917                    139904
# ...

# %%
diff_description = (all_crypto_15.describe() - all_crypto_15.interpolate(methode = 'polynomial').describe()) / all_crypto_15.describe() * 100

# %%
diff_description
# Out:
#        close_AAVEUSDT  close_AUTOUSDT  close_BCHUSDT  close_BETHUSDT
# count       -0.109172       -0.084418      -0.130850       -0.181951  \
# mean        -0.046787       -0.105403      -0.048801       -0.012257
# std         -0.028077       -0.062282      -0.015663        0.017974
# min          0.000000        0.000000       0.000000        0.000000
# 25%         -0.012547       -0.029294      -0.156600       -0.005350
# 50%         -0.069735       -0.075339      -0.069262       -0.005033
# 75%         -0.059547       -0.073809      -0.105929       -0.001140
# max          0.000000        0.000000       0.000000        0.000000
#
#        close_BIFIUSDT  close_BNBUSDT  close_BTCUSDT  close_ETHUSDT
# count       -0.014286      -0.285018      -0.287520      -0.287520  \
# mean         0.001262       0.165449       0.095018       0.109657
# std          0.006986       0.033006       0.028009       0.069716
# min          0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# We made few changes in the mean by adding value, and small changes in quantile repartition of course, but no min or max so we consider that we'll be using those data interpolated to continue

# %%
all_crypto_15.interpolate(methode = 'polynomial').to_csv('./data/ALL_15_interpol.csv')
