# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_crypto_15 = pd.read_csv('../data/ALL_15.csv')
#all_crypto_15.dropna(inplace = True)


all_crypto_15.set_index(['open_time'],inplace =True)
all_crypto_15.index = pd.to_datetime(all_crypto_15.index)
all_crypto_15.head()
# Out:
#                      close_AAVEUSDT  close_AUTOUSDT  close_BCHUSDT
# open_time
# 2017-08-17 04:00:00             NaN             NaN            NaN  \
# 2017-08-17 04:15:00             NaN             NaN            NaN
# 2017-08-17 04:30:00             NaN             NaN            NaN
# 2017-08-17 04:45:00             NaN             NaN            NaN
# 2017-08-17 05:00:00             NaN             NaN            NaN
#
#                      close_BETHUSDT  close_BIFIUSDT  close_BNBUSDT
# open_time
# 2017-08-17 04:00:00             NaN             NaN            NaN  \
# 2017-08-17 04:15:00             NaN             NaN            NaN
# 2017-08-17 04:30:00             NaN             NaN            NaN
# 2017-08-17 04:45:00             NaN             NaN            NaN
# 2017-08-17 05:00:00             NaN             NaN            NaN
#
#                      close_BTCUSDT  close_ETHUSDT  close_GMXUSDT
# open_time
# 2017-08-17 04:00:00        4261.48         301.13            NaN  \
# 2017-08-17 04:15:00        4261.48         298.00            NaN
# 2017-08-17 04:30:00        4280.00         299.39            NaN
# 2017-08-17 04:45:00        4310.07         299.60            NaN
# 2017-08-17 05:00:00        4308.83         301.61            NaN
#
#                      close_GNOUSDT  close_ILVUSDT  close_KP3RUSDT
# open_time
# 2017-08-17 04:00:00            NaN            NaN             NaN  \
# 2017-08-17 04:15:00            NaN            NaN             NaN
# 2017-08-17 04:30:00            NaN            NaN             NaN
# 2017-08-17 04:45:00            NaN            NaN             NaN
# 2017-08-17 05:00:00            NaN            NaN             NaN
#
#                      close_LTCUSDT  close_MKRUSDT  close_PAXGUSDT
# open_time
# 2017-08-17 04:00:00            NaN            NaN             NaN  \
# 2017-08-17 04:15:00            NaN            NaN             NaN
# 2017-08-17 04:30:00            NaN            NaN             NaN
# 2017-08-17 04:45:00            NaN            NaN             NaN
# 2017-08-17 05:00:00            NaN            NaN             NaN
#
#                      close_QNTUSDT  close_QUICKUSDT  close_XMRUSDT
# open_time
# 2017-08-17 04:00:00            NaN              NaN            NaN  \
# 2017-08-17 04:15:00            NaN              NaN            NaN
# 2017-08-17 04:30:00            NaN              NaN            NaN
# 2017-08-17 04:45:00            NaN              NaN            NaN
# 2017-08-17 05:00:00            NaN              NaN            NaN
#
#                      close_YFIIUSDT  close_YFIUSDT
# open_time
# 2017-08-17 04:00:00             NaN            NaN
# 2017-08-17 04:15:00             NaN            NaN
# 2017-08-17 04:30:00             NaN            NaN
# 2017-08-17 04:45:00             NaN            NaN
# 2017-08-17 05:00:00             NaN            NaN

# %%
all_crypto_15.loc['2020']
# Out:
#                      close_AAVEUSDT  close_AUTOUSDT  close_BCHUSDT
# open_time
# 2020-01-01 00:00:00             NaN             NaN         204.39  \
# 2020-01-01 00:15:00             NaN             NaN         204.12
# 2020-01-01 00:30:00             NaN             NaN         204.44
# 2020-01-01 00:45:00             NaN             NaN         204.54
# 2020-01-01 01:00:00             NaN             NaN         204.44
# ...                             ...             ...            ...
# 2020-12-31 22:45:00          86.189             NaN         344.47
# 2020-12-31 23:00:00          86.766             NaN         343.99
# 2020-12-31 23:15:00          88.410             NaN         343.57
# 2020-12-31 23:30:00          88.136             NaN         344.02
# 2020-12-31 23:45:00          87.901             NaN         341.70
#
#                      close_BETHUSDT  close_BIFIUSDT  close_BNBUSDT
# open_time
# 2020-01-01 00:00:00             NaN             NaN        13.7100  \
# 2020-01-01 00:15:00             NaN             NaN        13.7076
# 2020-01-01 00:30:00             NaN             NaN        13.7129
# 2020-01-01 00:45:00             NaN             NaN        13.7043
# 2020-01-01 01:00:00             NaN             NaN        13.6953
# ...                             ...             ...            ...
# 2020-12-31 22:45:00             NaN             NaN        37.1937
# 2020-12-31 23:00:00             NaN             NaN        37.1503
# 2020-12-31 23:15:00             NaN             NaN        37.2096
# 2020-12-31 23:30:00             NaN             NaN        37.2695
# 2020-12-31 23:45:00             NaN             NaN        37.2074
#
#                      close_BTCUSDT  close_ETHUSDT  close_GMXUSDT
# open_time
# 2020-01-01 00:00:00        7186.68         129.02            NaN  \
# 2020-01-01 00:15:00        7183.06         129.00            NaN
# 2020-01-01 00:30:00        7183.49         129.00            NaN
# 2020-01-01 00:45:00        7180.21         128.85            NaN
# 2020-01-01 01:00:00        7177.41         128.85            NaN
# ...                            ...            ...            ...
# 2020-12-31 22:45:00       29119.00         740.88            NaN
# 2020-12-31 23:00:00       29059.99         739.23            NaN
# 2020-12-31 23:15:00       29066.47         740.19            NaN
# 2020-12-31 23:30:00       28926.55         738.57            NaN
# 2020-12-31 23:45:00       28811.00         734.21            NaN
#
#                      close_GNOUSDT  close_ILVUSDT  close_KP3RUSDT
# open_time
# 2020-01-01 00:00:00            NaN            NaN             NaN  \
# 2020-01-01 00:15:00            NaN            NaN             NaN
# 2020-01-01 00:30:00            NaN            NaN             NaN
# 2020-01-01 00:45:00            NaN            NaN             NaN
# 2020-01-01 01:00:00            NaN            NaN             NaN
# ...                            ...            ...             ...
# 2020-12-31 22:45:00            NaN            NaN             NaN
# 2020-12-31 23:00:00            NaN            NaN             NaN
# 2020-12-31 23:15:00            NaN            NaN             NaN
# 2020-12-31 23:30:00            NaN            NaN             NaN
# 2020-12-31 23:45:00            NaN            NaN             NaN
#
#                      close_LTCUSDT  close_MKRUSDT  close_PAXGUSDT
# open_time
# 2020-01-01 00:00:00          41.20            NaN             NaN  \
# 2020-01-01 00:15:00          41.20            NaN             NaN
# 2020-01-01 00:30:00          41.27            NaN             NaN
# 2020-01-01 00:45:00          41.28            NaN             NaN
# 2020-01-01 01:00:00          41.27            NaN             NaN
# ...                            ...            ...             ...
# 2020-12-31 22:45:00         124.07         587.87         1935.74
# 2020-12-31 23:00:00         124.45         583.99         1937.92
# 2020-12-31 23:15:00         124.79         590.62         1935.74
# 2020-12-31 23:30:00         124.94         589.08         1931.36
# 2020-12-31 23:45:00         123.84         584.44         1934.00
#
#                      close_QNTUSDT  close_QUICKUSDT  close_XMRUSDT
# open_time
# 2020-01-01 00:00:00            NaN              NaN          44.65  \
# 2020-01-01 00:15:00            NaN              NaN          44.59
# 2020-01-01 00:30:00            NaN              NaN          44.55
# 2020-01-01 00:45:00            NaN              NaN          44.63
# 2020-01-01 01:00:00            NaN              NaN          44.56
# ...                            ...              ...            ...
# 2020-12-31 22:45:00            NaN              NaN         155.62
# 2020-12-31 23:00:00            NaN              NaN         155.94
# 2020-12-31 23:15:00            NaN              NaN         156.94
# 2020-12-31 23:30:00            NaN              NaN         156.83
# 2020-12-31 23:45:00            NaN              NaN         156.18
#
#                      close_YFIIUSDT  close_YFIUSDT
# open_time
# 2020-01-01 00:00:00             NaN            NaN
# 2020-01-01 00:15:00             NaN            NaN
# 2020-01-01 00:30:00             NaN            NaN
# 2020-01-01 00:45:00             NaN            NaN
# 2020-01-01 01:00:00             NaN            NaN
# ...                             ...            ...
# 2020-12-31 22:45:00         1616.49       22760.95
# 2020-12-31 23:00:00         1609.86       22753.40
# 2020-12-31 23:15:00         1614.86       22648.97
# 2020-12-31 23:30:00         1611.78       22863.18
# 2020-12-31 23:45:00         1616.13       22844.29
#
# [35136 rows x 20 columns]

# %%
all_crypto_15_norm = all_crypto_15 / all_crypto_15.iloc[0,:]

# %%
all_crypto_15_norm.plot()
plt.legend(bbox_to_anchor = (1,1))

# %%
pd.plotting.scatter_matrix(all_crypto_15,alpha = 0.1,figsize = (16,20))
# Out:
# array([[<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_AAVEUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_AAVEUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_AUTOUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_AUTOUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_BCHUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_BCHUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_BETHUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_BETHUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_BIFIUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_BIFIUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_BNBUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_BNBUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_BTCUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_BTCUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_ETHUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_ETHUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_GMXUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_GMXUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_GNOUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_GNOUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_ILVUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_ILVUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_KP3RUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_KP3RUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_LTCUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_LTCUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_MKRUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_MKRUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_PAXGUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_PAXGUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_QNTUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_QNTUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_QUICKUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_QUICKUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_XMRUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_XMRUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_YFIIUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_YFIIUSDT'>],
#        [<AxesSubplot:xlabel='close_AAVEUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_AUTOUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_BCHUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_BETHUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_BIFIUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_BNBUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_BTCUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_ETHUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_GMXUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_GNOUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_ILVUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_KP3RUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_LTCUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_MKRUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_PAXGUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_QNTUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_QUICKUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_XMRUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_YFIIUSDT', ylabel='close_YFIUSDT'>,
#         <AxesSubplot:xlabel='close_YFIUSDT', ylabel='close_YFIUSDT'>]],
#       dtype=object)

# %%
all_crypto_15_return = np.log(all_crypto_15).diff().dropna()
all_crypto_15_return.index = pd.to_datetime(all_crypto_15_return.index)

# %%
corr = all_crypto_15_return.corr()

# %%
pd.plotting.scatter_matrix(all_crypto_15_return,alpha = 0.1,figsize = (16,20))
plt.xticks(rotation = 45)
# Out:
# (array([-0.05 , -0.025,  0.   ,  0.025,  0.05 ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize = (15,15))
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
all_years = all_crypto_15_return.index.year.unique()
all_years
# Out:
# Index([2023], dtype='int32', name='open_time')

# %%
# fig,ax = plt.subplots(len(all_years),2,figsize= (17,20))
# for i  in range(len(all_years)) :
#     year = all_years[i]
#     model_loaded = model_calibrated.load(f'../models/OLS/ols_{year}.pk')
#     spread = working_df.loc[str(year)]['close_BTCUSDT'] - model_loaded.predict()

#     xmin = working_df.loc[str(year)]['close_BTCUSDT'].index[0]
#     xmax = working_df.loc[str(year)]['close_BTCUSDT'].index[-1]

#     ax[i][1].plot(spread, label = year)
#     ax[i][1].hlines(np.std(spread),xmin = xmin,xmax = xmax,color = 'r')
#     ax[i][1].hlines(-np.std(spread),xmin = xmin,xmax = xmax,color = 'r')
#     ax[i][1].set_title(f'Spread Year : {year}')

#     ax[i][0].plot(working_df.loc[str(year)]['close_BTCUSDT'])
#     ax[i][0].set_title(f'BTC Year : {year}')
